# %% [markdown]
# # Mean
# The mean value is the average value.

# %% [markdown]
# Use the NumPy mean() method to find the average speed:

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print(x)
# Out:
# 89.76923076923077

# %%
print(round(x))
# Out:
# 90.0

# %% [markdown]
# # Median
#
# The median value is the value in the middle, after you have sorted all the values:

# %% [markdown]
# Use the NumPy median() method to find the middle value:

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)
# Out:
# 87.0

# %% [markdown]
# If there are two numbers in the middle, divide the sum of those numbers by two.

# %%
import numpy

speed = [99,86,87,88,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)
# Out:
# 86.5

# %% [markdown]
# # Mode
#
# The Mode value is the value that appears the most number of times:

# %% [markdown]
# Use the SciPy mode() method to find the number that appears the most:

# %%
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=array([86]), count=array([3]))

# %% [markdown]
# # Variance
# Use the NumPy var() method to find the variance:

# %%
import numpy

speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %% [markdown]
# # Standard Deviation
# Standard deviation is a number that describes how spread out the values are.
#
# A low standard deviation means that most of the numbers are close to the mean (average) value.
#
# A high standard deviation means that the values are spread out over a wider range.
#
# Example: This time we have registered the speed of 7 cars:

# %% [markdown]
# Use the NumPy std() method to find the standard deviation:

# %%
import numpy

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
import numpy

speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)
# Out:
# 37.84501153334721

# %% [markdown]
# # Percentiles
# Percentiles are used in statistics to give you a number that describes the value that a given percent of the values are lower than.

# %%
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %% [markdown]
# Let's take our example

# %%
data1 = [30, 36, 47, 50, 52, 52, 56, 60, 63, 70, 70, 110]
x = numpy.percentile(data1, 25)
print (x)
# Out:
# 49.25

# %%
x = numpy.percentile(data1, 75)
print (x)
# Out:
# 64.75

# %% [markdown]
# https://www.tutorialspoint.com/python_data_science/index.htm

# %% [markdown]
# # Reading a CSV File

# %%
import pandas as pd
data = pd.read_csv('/content/sample_data/file1.csv')
print (data)
# Out:
#    id    name  salary  start_date        dept
# 0   1    Rick  623.30  2012-01-01          IT
# 1   2     Dan  515.20  2013-09-23  Operations
# 2   3   Tusar  611.00  2014-11-15          IT
# 3   4    Ryan  729.00  2014-05-11          HR
# 4   5    Gary  843.25  2015-03-27     Finance
# 5   6   Rasmi  578.00  2013-05-21          IT
# 6   7  Pranab  632.80  2013-07-30  Operations
# 7   8    Guru  722.50  2014-06-17     Finance

# %% [markdown]
# https://www.tutorialspoint.com/python_data_science/python_processing_csv_data.htm

# %% [markdown]
# Reading Specific Rows

# %%
# Slice the result for first 5 rows
print (data[0:5]['salary'])
# Out:
# 0    623.30
# 1    515.20
# 2    611.00
# 3    729.00
# 4    843.25
# Name: salary, dtype: float64

# %%
print (data['salary'])
# Out:
# 0    623.30
# 1    515.20
# 2    611.00
# 3    729.00
# 4    843.25
# 5    578.00
# 6    632.80
# 7    722.50
# Name: salary, dtype: float64

# %%
sal = data[0:8]['salary']
print (sal)
# Out:
# 0    623.30
# 1    515.20
# 2    611.00
# 3    729.00
# 4    843.25
# 5    578.00
# 6    632.80
# 7    722.50
# Name: salary, dtype: float64

# %% [markdown]
# # Calculating mean of salary

# %%
print (numpy.mean(sal))
# Out:
# 656.88125

# %% [markdown]
# # Box plot explained
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %% [markdown]
# https://matplotlib.org/3.3.1/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py
